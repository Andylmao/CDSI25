# %%
import os
import sys

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import IPython.display as ipd
from IPython.display import Audio, display, Markdown
import librosa
import librosa.display

# %% [markdown]
# # Norlmalizado de audios a 16 kHz y mono

# %%
import os
import librosa
import soundfile as sf


input_folder = "AudioVoiceData/audDataStdrWav/Metod3Wav"  
output_folder = "AudioVoiceData/audDataStdrWav/met3norm16" 
target_sr = 16000  
mono = True  


def normalize_audio(input_path, output_path, target_sr, mono):
    
    y, sr = librosa.load(input_path, sr=target_sr, mono=mono)
    y_normalized = librosa.util.normalize(y)
    sf.write(output_path, y_normalized, target_sr)


for filename in os.listdir(input_folder):
    if filename.endswith(".wav"): 
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)
        normalize_audio(input_path, output_path, target_sr, mono)
        print(f"Audio normalizado guardado: {output_path}")

print("Completado")
# Out:
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\AndresCalzada-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\AndresCalzada-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\AndresCalzada-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\AndresCalzada-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\AndresCalzada-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\AndresCalzada-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\AndresCalzada-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\AndresCalzada-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\AndresCalzada-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\AndresCalzada-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\ArathDaniela-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\ArathDaniela-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\ArathDaniela-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\ArathDaniela-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\ArathDaniela-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\ArathDaniela-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\ArathDaniela-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\ArathDaniela-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\ArathDaniela-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\ArathDaniela-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ariana-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ariana-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ariana-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ariana-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ariana-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ariana-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ariana-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ariana-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ariana-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ariana-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Camila-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Camila-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Camila-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Camila-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Camila-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Camila-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Camila-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Camila-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Camila-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Camila-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Cielo-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Cielo-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Cielo-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Cielo-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Cielo-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Cielo-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Cielo-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Cielo-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Cielo-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Cielo-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\DafneA-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\DafneA-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\DafneA-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\DafneA-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\DafneA-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\DafneA-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\DafneA-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\DafneA-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\DafneA-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\DafneA-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel2-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel2-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel2-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel2-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel2-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel2-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel2-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel2-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel2-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Daniel2-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\David-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\David-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\David-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\David-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\David-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\David-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\David-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\David-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\David-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\David-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Didier-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Didier-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Didier-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Didier-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Didier-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Didier-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Didier-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Didier-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Didier-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Didier-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Erik-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Erik-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Erik-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Erik-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Erik-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Erik-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Erik-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Erik-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Erik-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Erik-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Esther-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Esther-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Esther-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Esther-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Esther-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Esther-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Esther-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Esther-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Esther-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Esther-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Francisco-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Francisco-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Francisco-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Francisco-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Francisco-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Francisco-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Francisco-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Francisco-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Francisco-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Francisco-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ignacio-03_1.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ignacio-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ignacio-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ignacio-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ignacio-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ignacio-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ignacio-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ignacio-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ignacio-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Ignacio-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Irma-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Irma-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Irma-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Irma-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Irma-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Irma-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Irma-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Irma-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Irma-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Irma-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\JesusAntonio-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\JesusAntonio-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\JesusAntonio-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\JesusAntonio-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\JesusAntonio-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\JesusAntonio-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\JesusAntonio-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\JesusAntonio-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\JesusAntonio-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\JesusAntonio-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Joan-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Joan-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Joan-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Joan-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Joan-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Joan-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Joan-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Joan-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Joan-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Joan-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Lex-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Lex-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Lex-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Lex-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Lex-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Lex-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Lex-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Lex-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Lex-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Lex-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\LuisG-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\LuisG-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\LuisG-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\LuisG-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\LuisG-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\LuisG-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\LuisG-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\LuisG-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\LuisG-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\LuisG-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Maria-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Maria-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Maria-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Maria-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Maria-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Maria-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Maria-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Maria-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Maria-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Maria-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Mariana-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Mariana-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Mariana-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Mariana-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Mariana-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Mariana-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Mariana-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Mariana-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Mariana-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Mariana-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Marlon-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Marlon-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Marlon-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Marlon-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Marlon-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Marlon-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Marlon-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Marlon-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Marlon-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Marlon-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-06.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-07.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-09.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-11.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-12.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-13.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-14.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-15.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Nula-9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\RamosBetancourt-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\RamosBetancourt-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\RamosBetancourt-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\RamosBetancourt-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\RamosBetancourt-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\RamosBetancourt-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\RamosBetancourt-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\RamosBetancourt-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\RamosBetancourt-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\RamosBetancourt-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Sergio-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Sergio-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Sergio-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Sergio-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Sergio-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Sergio-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Sergio-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Sergio-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Sergio-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Sergio-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Vanessa-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Vanessa-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Vanessa-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Vanessa-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Vanessa-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Vanessa-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Vanessa-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Vanessa-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Vanessa-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Vanessa-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yoselin Estudillo-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yoselin Estudillo-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yoselin Estudillo-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yoselin Estudillo-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yoselin Estudillo-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yoselin Estudillo-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yoselin Estudillo-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yoselin Estudillo-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yoselin Estudillo-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yoselin Estudillo-03_9.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yosira-03_01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yosira-03_10.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yosira-03_2.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yosira-03_3.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yosira-03_4.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yosira-03_5.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yosira-03_6.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yosira-03_7.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yosira-03_8.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav/met3norm16\Yosira-03_9.wav
# Completado

# %% [markdown]
# # Data augmentation

# %%
from audiomentations import Compose, AddGaussianNoise, PitchShift, TimeStretch


input_folder = "AudioVoiceData/audDataStdrWav/met1norm16"  
output_folder = "AudioVoiceData/audDataStdrWav/met1norm16"  
target_sr = 16000 
num_augmentations = 1 

augmenter = Compose([
    AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.015, p=0.5), 
    PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
    TimeStretch(min_rate=0.8, max_rate=1.2, p=0.5), 
])


def augment_audio(input_path, output_path):

    y, sr = librosa.load(input_path, sr=target_sr)
    y_augmented = augmenter(y, sr)
    sf.write(output_path, y_augmented, target_sr)


for filename in os.listdir(input_folder):
    if filename.endswith(".wav"):
        base_name = filename.split("_")[0]  
        audio_number = int(filename.split("_")[1].split(".")[0])  
        
      
        start_number = audio_number + 1
        
      
        for i in range(num_augmentations):
            
            new_audio_number = start_number + i
            output_filename = f"{base_name}_{new_audio_number:02d}.wav"  
            output_path = os.path.join(output_folder, output_filename)
            
            # Aplicar aumentación
            input_path = os.path.join(input_folder, filename)
            augment_audio(input_path, output_path)
            print(f"Audio aumentado guardado: {output_path}")

print("Completado")
# Out:
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\AndresCalzada-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\AndresCalzada-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\AndresCalzada-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\AndresCalzada-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\AndresCalzada-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\AndresCalzada-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\AndresCalzada-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\AndresCalzada-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\AndresCalzada-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\AndresCalzada-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\ArathDaniela-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\ArathDaniela-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\ArathDaniela-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\ArathDaniela-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\ArathDaniela-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\ArathDaniela-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\ArathDaniela-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\ArathDaniela-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\ArathDaniela-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\ArathDaniela-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ariana-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ariana-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ariana-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ariana-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ariana-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ariana-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ariana-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ariana-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ariana-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ariana-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Camila-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Camila-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Camila-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Camila-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Camila-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Camila-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Camila-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Camila-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Camila-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Camila-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Cielo-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Cielo-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Cielo-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Cielo-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Cielo-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Cielo-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Cielo-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Cielo-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Cielo-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Cielo-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\DafneA-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\DafneA-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\DafneA-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\DafneA-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\DafneA-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\DafneA-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\DafneA-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\DafneA-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\DafneA-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\DafneA-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel2-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel2-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel2-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel2-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel2-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel2-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel2-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel2-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel2-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Daniel2-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\David-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\David-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\David-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\David-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\David-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\David-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\David-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\David-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\David-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\David-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Didier-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Didier-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Didier-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Didier-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Didier-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Didier-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Didier-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Didier-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Didier-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Didier-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Erik-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Erik-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Erik-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Erik-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Erik-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Erik-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Erik-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Erik-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Erik-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Erik-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Esther-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Esther-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Esther-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Esther-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Esther-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Esther-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Esther-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Esther-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Esther-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Esther-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Francisco-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Francisco-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Francisco-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Francisco-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Francisco-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Francisco-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Francisco-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Francisco-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Francisco-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Francisco-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ignacio-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ignacio-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ignacio-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ignacio-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ignacio-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ignacio-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ignacio-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ignacio-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ignacio-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Ignacio-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Irma-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Irma-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Irma-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Irma-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Irma-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Irma-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Irma-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Irma-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Irma-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Irma-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\JesusAntonio-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\JesusAntonio-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\JesusAntonio-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\JesusAntonio-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\JesusAntonio-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\JesusAntonio-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\JesusAntonio-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\JesusAntonio-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\JesusAntonio-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\JesusAntonio-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Joan-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Joan-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Joan-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Joan-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Joan-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Joan-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Joan-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Joan-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Joan-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Joan-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Lex-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Lex-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Lex-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Lex-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Lex-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Lex-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Lex-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Lex-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Lex-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Lex-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\LuisG-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\LuisG-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\LuisG-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\LuisG-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\LuisG-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\LuisG-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\LuisG-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\LuisG-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\LuisG-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\LuisG-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Maria-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Maria-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Maria-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Maria-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Maria-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Maria-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Maria-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Maria-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Maria-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Maria-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Mariana-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Mariana-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Mariana-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Mariana-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Mariana-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Mariana-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Mariana-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Mariana-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Mariana-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Mariana-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Marlon-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Marlon-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Marlon-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Marlon-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Marlon-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Marlon-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Marlon-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Marlon-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Marlon-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Marlon-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\RamosBetancourt-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\RamosBetancourt-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\RamosBetancourt-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\RamosBetancourt-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\RamosBetancourt-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\RamosBetancourt-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\RamosBetancourt-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\RamosBetancourt-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\RamosBetancourt-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\RamosBetancourt-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Sergio-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Sergio-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Sergio-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Sergio-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Sergio-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Sergio-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Sergio-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Sergio-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Sergio-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Sergio-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Vanessa-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Vanessa-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Vanessa-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Vanessa-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Vanessa-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Vanessa-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Vanessa-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Vanessa-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Vanessa-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Vanessa-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yoselin Estudillo-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yoselin Estudillo-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yoselin Estudillo-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yoselin Estudillo-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yoselin Estudillo-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yoselin Estudillo-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yoselin Estudillo-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yoselin Estudillo-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yoselin Estudillo-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yoselin Estudillo-01_10.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yosira-01_02.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yosira-01_11.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yosira-01_03.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yosira-01_04.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yosira-01_05.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yosira-01_06.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yosira-01_07.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yosira-01_08.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yosira-01_09.wav
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met1norm16\Yosira-01_10.wav
# Completado

# %% [markdown]
# # Extraccion de caracteristicas MFCC y etiquetado de los datos

# %%
import os
import librosa
import numpy as np
import pandas as pd


input_folder = "AudioVoiceData/audDataStdrWav/met1norm16"  
target_sr = 16000  
n_mfcc = 13  


X = []  
y = []  


def extract_mfcc(input_path):
    
    y, sr = librosa.load(input_path, sr=target_sr)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    mfcc_mean = np.mean(mfcc, axis=1)
    
    return mfcc_mean


for filename in os.listdir(input_folder):
    if filename.endswith(".wav"):  
      
        input_path = os.path.join(input_folder, filename)
        mfcc = extract_mfcc(input_path)
        X.append(mfcc)
        
      
        label = filename.split("-")[0]  
        y.append(label)


X = np.array(X)
y = np.array(y)


df = pd.DataFrame(X, columns=[f"MFCC_{i+1}" for i in range(n_mfcc)])
df["Label"] = y  
output_csv = "AudioVoiceData/mfcc_features.csv"
df.to_csv(output_csv, index=False)

print(f"MFCC guardados en: {output_csv}")
# Out:
# MFCC guardados en: AudioVoiceData/mfcc_features.csv
