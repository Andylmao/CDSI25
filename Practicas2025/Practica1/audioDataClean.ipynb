# %%
import os
import sys
import librosa
import soundfile as sf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import IPython.display as ipd
from IPython.display import Audio, display, Markdown
import librosa
import librosa.display

# %% [markdown]
# # Norlmalizado de audios a 16 kHz y mono

# %%
import os
import librosa
import soundfile as sf


input_folder = "AudioVoiceData/audDataStdrWav"  
output_folder = "AudioVoiceData/audDataStdrWav" 
target_sr = 16000  
mono = True  


def normalize_audio(input_path, output_path, target_sr, mono):
    
    y, sr = librosa.load(input_path, sr=target_sr, mono=mono)
    y_normalized = librosa.util.normalize(y)
    sf.write(output_path, y_normalized, target_sr)


for filename in os.listdir(input_folder):
    if filename.endswith(".wav"): 
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)
        normalize_audio(input_path, output_path, target_sr, mono)
        print(f"Audio normalizado guardado: {output_path}")

print("Completado")
# Out:
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-01.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-02.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-03.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-04.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-05.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-06.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-07.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-08.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-11.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-12.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-13.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-14.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-15.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-16.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-17.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-18.wav
# Audio normalizado guardado: AudioVoiceData/audDataStdrWav\Ruido-19.wav
# Completado

# %% [markdown]
# # Data augmentation

# %%
from audiomentations import Compose, AddGaussianNoise, PitchShift, TimeStretch


input_folder = "AudioVoiceData/audDataStdrWav/met3norm16"  
output_folder = "AudioVoiceData/audDataStdrWav/met3norm16"  
target_sr = 16000 
num_augmentations = 1 

augmenter = Compose([
    AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.015, p=0.5), 
    PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
    TimeStretch(min_rate=0.8, max_rate=1.2, p=0.5), 
])


def augment_audio(input_path, output_path):

    y, sr = librosa.load(input_path, sr=target_sr)
    y_augmented = augmenter(y, sr)
    sf.write(output_path, y_augmented, target_sr)


for filename in os.listdir(input_folder):
    if filename.endswith(".wav"):
        base_name = filename.split("_")[0]  
        audio_number = int(filename.split("_")[1].split(".")[0])  
        
      
        start_number = audio_number + 1
        
      
        for i in range(num_augmentations):
            
            new_audio_number = start_number + i
            output_filename = f"{base_name}_{new_audio_number:02d}.wav"  
            output_path = os.path.join(output_folder, output_filename)
            
            # Aplicar aumentación
            input_path = os.path.join(input_folder, filename)
            augment_audio(input_path, output_path)
            print(f"Audio aumentado guardado: {output_path}")

print("Completado")
# Out:
# Audio aumentado guardado: AudioVoiceData/audDataStdrWav/met3norm16
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 26
#      24 if filename.endswith(".wav"):
#      25     base_name = filename.split("_")[0]
# ---> 26     audio_number = int(filename.split("_")[1].split(".")[0])
#      29     start_number = audio_number + 1
#      32     for i in range(num_augmentations):
#
# IndexError: list index out of range

# %% [markdown]
# # Extraccion de caracteristicas MFCC y etiquetado de los datos

# %%
import os
import librosa
import numpy as np
import pandas as pd


input_folder = "AudioVoiceData/audDataStdrWav/met1norm16"  
target_sr = 16000  
n_mfcc = 13  


X = []  
y = []  


def extract_mfcc(input_path):
    
    y, sr = librosa.load(input_path, sr=target_sr)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    mfcc_mean = np.mean(mfcc, axis=1)
    
    return mfcc_mean


for filename in os.listdir(input_folder):
    if filename.endswith(".wav"):  
      
        input_path = os.path.join(input_folder, filename)
        mfcc = extract_mfcc(input_path)
        X.append(mfcc)
        
      
        label = filename.split("-")[0]  
        y.append(label)


X = np.array(X)
y = np.array(y)


df = pd.DataFrame(X, columns=[f"MFCC_{i+1}" for i in range(n_mfcc)])
df["Label"] = y  
output_csv = "AudioVoiceData/mfcc_features.csv"
df.to_csv(output_csv, index=False)

print(f"MFCC guardados en: {output_csv}")
# Out:
# MFCC guardados en: AudioVoiceData/mfcc_features.csv

# %% [markdown]
# ### Con el fin de mejorar la precision del modelo se prueba extrayendo nuevas caracteristicas para cada audio

# %%
import os
import librosa
import numpy as np
import pandas as pd


input_folder = "AudioVoiceData/audDataStdrWav/met2norm16"  
output_csv = "AudioVoiceData/mfcc_featuresMeth2.csv"  
target_sr = 16000  
n_mfcc = 13  
n_mels = 40 
n_chroma = 12  


def extract_features(input_path):
    y, sr = librosa.load(input_path, sr=target_sr)
    
   
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    mfcc_mean = np.mean(mfcc, axis=1)  
    mfcc_std = np.std(mfcc, axis=1)   
    

    mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels)
    mel_mean = np.mean(mel_spectrogram, axis=1)  
    mel_std = np.std(mel_spectrogram, axis=1)   
    
 
    chroma = librosa.feature.chroma_stft(y=y, sr=sr, n_chroma=n_chroma)
    chroma_mean = np.mean(chroma, axis=1) 
    chroma_std = np.std(chroma, axis=1)    
    
    
    features = np.concatenate([mfcc_mean, mfcc_std, mel_mean, mel_std, chroma_mean, chroma_std])
    return features


X = [] 
y = []  


for filename in os.listdir(input_folder):
    if filename.endswith(".wav"):
       
        input_path = os.path.join(input_folder, filename)
        features = extract_features(input_path)
        X.append(features)
        
       
        label = filename.split("-")[0]  
        y.append(label)


columns = (
    [f"MFCC_{i+1}_mean" for i in range(n_mfcc)] +
    [f"MFCC_{i+1}_std" for i in range(n_mfcc)] +
    [f"Mel_{i+1}_mean" for i in range(n_mels)] +
    [f"Mel_{i+1}_std" for i in range(n_mels)] +
    [f"Chroma_{i+1}_mean" for i in range(n_chroma)] +
    [f"Chroma_{i+1}_std" for i in range(n_chroma)]
)

df = pd.DataFrame(X, columns=columns)
df["Label"] = y


df.to_csv(output_csv, index=False)

print(f"Características guardadas en: {output_csv}")
# Out:
# Características guardadas en: AudioVoiceData/mfcc_featuresMeth2.csv
